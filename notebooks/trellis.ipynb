# %% [markdown]
# # **Introduction to Trellis API**
#
# Trellis is a platform designed to extract structured data, insights, and patterns from documents using advanced AI models. It provides a seamless workflow for document processing, offering tools for extraction, classification, summarization, and more. With its REST API and Python SDK, Trellis enables easy integration into various applications.
#
# ## **Core Features**
# 1. **Document Processing**: Handles various formats, including PDFs, images, and text files.
# 2. **Customizable Workflows**: Supports tailored operations like extraction, classification, and summarization.
# 3. **Scalability and Security**: Processes large datasets efficiently while ensuring data privacy.
#
# ## **Workflow Overview**
# 1. **Set Up a Project**: Create a project to organize your assets and transformations.
# 2. **Upload Documents**: Add files (e.g., PDFs or images) to your project.
# 3. **Define Transformations**: Specify tasks like extraction or summarization using custom prompts.
# 4. **Retrieve Results**: Access processed results via the API or SDK for analysis or storage.
#
# ## **Key Concepts**
# - **Assets**: Individual files (PDFs, images, etc.) uploaded for processing within a project.
# - **Projects**: Containers to manage assets and transformations, identified by a unique `proj_id`.
# - **Transformations**: Defined operations (e.g., extraction, classification, summarization) applied to assets.
# - **Operations**: Specific tasks within transformations, such as extracting dates or classifying content.
#
# ## **Key API Endpoints**
# 1. **Create a Project**:
#    - **Endpoint**: `/projects/create`
#    - **Method**: `POST`
#    - Purpose: Set up a project to manage assets and transformations.
# 2. **Upload an Asset**:
#    - **Endpoint**: `/assets/upload`
#    - **Method**: `POST`
#    - Purpose: Upload files (e.g., PDFs) for processing within a project.
# 3. **Create a Transformation**:
#    - **Endpoint**: `/transforms/create`
#    - **Method**: `POST`
#    - Purpose: Define operations such as data extraction or classification for the uploaded assets.
# 4. **Retrieve Results**:
#    - **Endpoint**: `/transforms/results`
#    - **Method**: `GET`
#    - Purpose: Access the processed results of transformations.
#
# ## **Authentication**
# Trellis requires an API key for authentication. Include the key in your request headers:
# ```bash
# Authorization: Bearer YOUR_API_KEY

# %% [markdown]
# ### **Using Trellis API for Dataset Processing**
#
# In this project, We used the Trellis API to automate the extraction of publication dates from a dataset of French administrative documents hosted on Hugging Face.
#
# #### **Workflow Overview**
# 1. **Project Creation**: A new Trellis project was created to manage the dataset files and transformations.
# 2. **File Upload**: Files from the dataset were uploaded to the project for processing.
# 3. **Custom Transformation**: A custom operation was defined using a detailed prompt to extract publication dates from the documents.
# 4. **Result Retrieval**: Extracted dates were retrieved via the API and compared against the dataset's gold-standard labels to evaluate performance.
#
# This process streamlined the extraction task, ensuring accuracy and efficiency in handling large datasets.

# %%
import pandas as pd
import requests

from typing import List, Dict

# %%
TRELLIS_API_KEY = "YOUR-API-KEY"
CREATE_PROJECT_URL = "https://api.runtrellis.com/v1/projects/create"
CREATE_TRANSFORM_URL = "https://api.runtrellis.com/v1/transforms/create"
EVENT_URL = "https://api.runtrellis.com/v1/events/subscriptions/actions/bulk"
UPLOAD_URL = "https://api.runtrellis.com/v1/assets/upload"

HEADERS = {
    "Authorization": TRELLIS_API_KEY,
    "Content-Type": "application/json",
    "accept": "application/json"
}

PROMPT = """
You are tasked with extracting the publication date from French administrative documents. 

The publication date can typically be found in the following places:
1. On the first page, specifically in the top-right corner, look for text after "Reçu en préfecture le." This is often the most reliable source of the publication date.
2. In a section titled "Approbation et modifications du règlement" or similar, often specified with phrases like "entre en vigueur le."
3. Elsewhere on the document where the date is explicitly linked to the document's publication or adoption.

Guidelines:
- Look for dates in formats such as "DD/MM/YYYY" or "D/M/YYYY or YYYY"
- Prioritize the date found after "Reçu en préfecture le" in the top-right corner of the first page. If this is unavailable, proceed to other sections.
- If multiple dates are present, prioritize the one explicitly linked to the document's publication or adoption.
- Return only the date in `DD/MM/YYYY` format.
- If no date is found, return "Date not found."

"""

# %%
def create_project(project_name: str) -> str:
    """Creates a Trellis project and returns the project ID."""
    try:
        payload = {"name": project_name}
        response = requests.post(CREATE_PROJECT_URL, json=payload, headers=HEADERS)
        response.raise_for_status()
        return response.json()["data"]["proj_id"]
    except requests.RequestException as e:
        raise RuntimeError(f"Error creating project: {e}") from e


def create_transform(proj_id: str, prompt: str) -> str:
    """Creates a Trellis transform and returns the transform ID."""
    try:
        payload = {
            "proj_id": proj_id,
            "transform_name": "publication_date_extraction",
            "transform_params": {
                "model": "trellis-premium",
                "mode": "document",
                "operations": [
                    {
                        "column_name": "publication_date",
                        "column_type": "text",
                        "transform_type": "extraction",
                        "task_description": prompt
                    }
                ]
            }
        }
        response = requests.post(CREATE_TRANSFORM_URL, json=payload, headers=HEADERS)
        response.raise_for_status()
        return response.json()["data"]["transform_id"]
    except requests.RequestException as e:
        raise RuntimeError(f"Error creating transform: {e}") from e


def configure_events(proj_id: str, transform_id: str):
    """Configures event subscriptions for the Trellis project."""
    try:
        payload = {
            "events_with_actions": [
                {
                    "event_type": "asset_uploaded",
                    "proj_id": proj_id,
                    "actions": [
                        {"type": "run_extraction", "proj_id": proj_id}
                    ]
                },
                {
                    "event_type": "asset_extracted",
                    "proj_id": proj_id,
                    "actions": [
                        {"type": "refresh_transform", "transform_id": transform_id}
                    ]
                }
            ]
        }
        response = requests.post(EVENT_URL, json=payload, headers=HEADERS)
        return response.raise_for_status()
    except requests.RequestException as e:
        raise RuntimeError(f"Error configuring events: {e}") from e


def upload_pdf(proj_id: str, pdf_urls: List[str]) -> List[str]:
    """Uploads PDF URLs to the Trellis project and returns the asset IDs."""
    try:
        payload = {"proj_id": proj_id, "urls": pdf_urls}
        response = requests.post(UPLOAD_URL, json=payload, headers=HEADERS)
        response.raise_for_status()
        return [data["asset_id"] for data in response.json()["data"]]
    except requests.RequestException as e:
        raise RuntimeError(f"Error uploading PDF: {e}") from e


def fetch_results(transform_id: str, asset_ids: List[str]) -> List[Dict]:
    """Fetches extraction results from Trellis."""
    try:
        url = f"https://api.runtrellis.com/v1/transforms/{transform_id}/results"
        payload = {"filters": {}, "asset_ids": asset_ids}
        response = requests.post(url, json=payload, headers=HEADERS)
        response.raise_for_status()
        return response.json()
    except requests.RequestException as e:
        raise RuntimeError(f"Error fetching results: {e}") from e

# %%
def process_publication_dates(pdf_url: str) -> List[str]:
    """
    Extracts publication date for a PDF URL
    """
    try:
        # Step 1: Create project
        proj_id = create_project("Date Extraction")
        
        # Step 2: Create transform
        transform_id = create_transform(proj_id, PROMPT)
        
        # Step 3: Configure events
        configure_events(proj_id, transform_id)
        
        # Step 4: Upload PDF and get asset IDs
        asset_ids = upload_pdf(proj_id, pdf_url)
        
        # Step 5: Fetch results
        results = fetch_results(transform_id, asset_ids)
        
        # Step 6: Extract the publication date from results
        column_definitions = results['metadata']['column_definitions']
        publication_date_id = next(
            (column["id"] for column in column_definitions if column["name"] == "publication_date"), 
            None
        )
        
        data = results.get("data", [])
        predicted_date = next(
            (item[publication_date_id] for item in data if publication_date_id in item), 
            "Date not found"
        )

        return predicted_date
    
    except Exception as e:
        print(f"Error during processing: {e}")

# %% [markdown]
# ## Preprocess Data

# %%
df1 = pd.read_csv("/Users/zeinab/Computational-Linguistics/M2/NLP in Industry/french-date-extractor/data/raw/original_data.csv")
df2 = pd.read_csv("/Users/zeinab/Computational-Linguistics/M2/NLP in Industry/french-date-extractor/data/raw/annotations.csv")

df1_subset = df1[["url", "cache"]]
df2_subset = df2[["url", "Gold published date"]]
df1_subset = df1_subset.rename(columns={"cache": "pdf_url"})
df2_subset = df2_subset.rename(columns={"Gold published date": "gold_date"})

merged_df = pd.merge(df1_subset, df2_subset, on="url", how="inner")
merged_df = merged_df.dropna()
merged_df = merged_df.drop(columns="url")
df = merged_df[~merged_df["pdf_url"].str.contains(r"\s", na=False)].reset_index(drop=True)
df.to_csv("/Users/zeinab/Computational-Linguistics/M2/NLP in Industry/french-date-extractor/data/processed/final_dataset.csv")

# %%
df.head(10)
# Out:
#                                              pdf_url   gold_date
# 0  https://datapolitics-public.s3.gra.io.cloud.ov...  16/01/2023
# 1  https://datapolitics-public.s3.gra.io.cloud.ov...  25/01/2023
# 2  https://datapolitics-public.s3.gra.io.cloud.ov...  02/02/2023
# 3  https://datapolitics-public.s3.gra.io.cloud.ov...  26/01/2023
# 4  https://datapolitics-public.s3.gra.io.cloud.ov...  16/01/2023
# 5  https://datapolitics-public.s3.gra.io.cloud.ov...  16/02/2023
# 6  https://datapolitics-public.s3.gra.io.cloud.ov...  22/02/2023
# 7  https://datapolitics-public.s3.gra.io.cloud.ov...  13/02/2023
# 8  https://datapolitics-public.s3.gra.io.cloud.ov...  09/03/2023
# 9  https://datapolitics-public.s3.gra.io.cloud.ov...  15/02/2023

# %% [markdown]
# ## Process all PDF URLs by calling API

# %%
urls = df['pdf_url'].to_list()
url_date_map = {}

# %%
for url in urls:
    date = process_publication_dates([url])
    print(date)
    url_date_map[url] = date
# Out:
# 16/01/2023
# 25/01/2023
# 02/02/2023
# 26/01/2023
# 16/01/2023
# 16/02/2023
# Error during processing: Error fetching results: 504 Server Error: Gateway Time-out for url: https://api.runtrellis.com/v1/transforms/transform_2pZpM3L0crCOKixyaw0Rjr0lAVM/results
# None
# 13/02/2023
# Error during processing: Error fetching results: 504 Server Error: Gateway Time-out for url: https://api.runtrellis.com/v1/transforms/transform_2pZpZx6QMVMRJQKqZdIj3TqEgWa/results
# None
# 15/02/2023
# 15/02/2023
# Error during processing: Error fetching results: 504 Server Error: Gateway Time-out for url: https://api.runtrellis.com/v1/transforms/transform_2pZps7uyhBQAkojj4nWr1DDsgMD/results
# None
# 16/02/2023
# 20/02/2023
# 08/02/2023
# 14/02/2023
# Error during processing: Error fetching results: 504 Server Error: Gateway Time-out for url: https://api.runtrellis.com/v1/transforms/transform_2pZqLlP1usAS3hOnBMEgPYExJP3/results
# None
# 10/02/2023
# 10/03/2023
# 30/01/2023
# Date not found.
# 10/01/2023
# 25/01/2023
# 12/01/2023
# 12/01/2023
# 16/02/2023
# Date not found.
# 14/01/2023
# 30/01/2023
# 19/01/2023
# 16/12/2022
# 20/02/2023
# 01/02/2023
# Error during processing: Error fetching results: 504 Server Error: Gateway Time-out for url: https://api.runtrellis.com/v1/transforms/transform_2pZrpkh6lwV1rbSirQpFSnRz3UZ/results
# None
# Error during processing: Error fetching results: 504 Server Error: Gateway Time-out for url: https://api.runtrellis.com/v1/transforms/transform_2pZryFcoYa62gb0oNWGQHXtEZdP/results
# None
# 03/11/2022
# 16/05/2023
# Error during processing: Error fetching results: 504 Server Error: Gateway Time-out for url: https://api.runtrellis.com/v1/transforms/transform_2pZsJtNb7c4Q0KZmbgAHm6ua6RZ/results
# None
# Date not found.
# 30/05/2023
# Error during processing: Error fetching results: 504 Server Error: Gateway Time-out for url: https://api.runtrellis.com/v1/transforms/transform_2pZsbStX7amWUDcTPS3m3czxUbD/results
# None
# 30/05/2023
# 27/03/2023
# 06/03/2023
# 13/03/2023
# 30/03/2017
# 29/03/2023
# 02/02/2023
# Error during processing: Error fetching results: 504 Server Error: Gateway Time-out for url: https://api.runtrellis.com/v1/transforms/transform_2pZtNMlJcxrVXLxOAmi1I1y1QUg/results
# None
# Error during processing: Error fetching results: 504 Server Error: Gateway Time-out for url: https://api.runtrellis.com/v1/transforms/transform_2pZtVn8drDs5N9DG9MdHAafX7R0/results
# None
# 23/02/2023
# 09/02/2023
# 2/03/2023
# 06/02/2023
# Error during processing: Error fetching results: 504 Server Error: Gateway Time-out for url: https://api.runtrellis.com/v1/transforms/transform_2pZtwtaz7gSG0dtyHvFDcDLgna1/results
# None
# Error during processing: Error fetching results: 504 Server Error: Gateway Time-out for url: https://api.runtrellis.com/v1/transforms/transform_2pZu5IHUB4MkZ0LMoXdkykurL8G/results
# None
# 06/02/2023
# 13/02/2023
# 27/02/2023
# 09/02/2023
# 01/06/2023
# 02/03/2023
# 27/03/2024
# 06/03/2023
# Date not found.
# 16/03/2023
# 29/06/2023
# 15/03/2023
# 13/03/2023
# 02/04/2023
# 30/05/2023
# Error during processing: Error fetching results: 504 Server Error: Gateway Time-out for url: https://api.runtrellis.com/v1/transforms/transform_2pZvaLi6JsutHdfMhAQVPMBzGoK/results
# None
# 29/03/2023
# 27/06/2023
# 27/02/2023
# Date not found.
# 23/02/2023
# Error during processing: Error fetching results: 504 Server Error: Gateway Time-out for url: https://api.runtrellis.com/v1/transforms/transform_2pZw7qPoOja02hj2JITuYGgziKz/results
# None
# 03/02/2023
# 06/02/2023
# 07/03/2023
# Date not found.
# Error during processing: Error fetching results: 504 Server Error: Gateway Time-out for url: https://api.runtrellis.com/v1/transforms/transform_2pZwbkiwCVwGVpHWBb83l0ytBR1/results
# None
# Error during processing: Error fetching results: 504 Server Error: Gateway Time-out for url: https://api.runtrellis.com/v1/transforms/transform_2pZwk9bj8oq5QLhpsA702wi18oB/results
# None
# 19/12/2023
# 26/02/2024
# Error during processing: Error fetching results: 504 Server Error: Gateway Time-out for url: https://api.runtrellis.com/v1/transforms/transform_2pZx4POQeTlTgS2hWcz7PxOj0Tx/results
# None
# Error during processing: Error fetching results: 504 Server Error: Gateway Time-out for url: https://api.runtrellis.com/v1/transforms/transform_2pZxCuavUrvkAj2gkCzKdFB7kOM/results
# None
# 03/03/2023
# 31/03/2023
# 13/02/2023
# 03/02/2023
# 08/02/2024
# 20/03/2023
# Date not found
# Error during processing: Error fetching results: 504 Server Error: Gateway Time-out for url: https://api.runtrellis.com/v1/transforms/transform_2pZxtiXrc8fYtKU11c06qVPkwFk/results
# None
# 13/02/2023
# 09/11/2023
# Error during processing: Error fetching results: 504 Server Error: Gateway Time-out for url: https://api.runtrellis.com/v1/transforms/transform_2pZyC7Nn6vfj5M3hBcGdGkE6iso/results
# None
# 16/01/2023
# 13/01/2023
# 26/01/2023
# Error during processing: Error fetching results: 504 Server Error: Gateway Time-out for url: https://api.runtrellis.com/v1/transforms/transform_2pZybOyQBGcjjLNkqCo3j6PWPpT/results
# None
# 27/02/2023
# Error during processing: Error fetching results: 504 Server Error: Gateway Time-out for url: https://api.runtrellis.com/v1/transforms/transform_2pZynMzzY8nynGYqGJg7rvDcNMC/results
# None
# 20/02/2023
# 08/02/2023
# 14/02/2023
# 20/03/2023
# 10/02/2023
# 21/02/2023
# 07/04/2023
# 07/04/2023
# 02/01/2023
# Error during processing: Error fetching results: 504 Server Error: Gateway Time-out for url: https://api.runtrellis.com/v1/transforms/transform_2pZzkjQoT8aY9fBA0AcKBGAB7nZ/results
# None
# 13/01/2023
# 20/10/2021
# 20/10/2021
# 25/01/2023
# 14/12/2022
# 27/03/2023
# 12/12/2022
# 20/12/2022
# 15/12/2022
# Error during processing: Error fetching results: 504 Server Error: Gateway Time-out for url: https://api.runtrellis.com/v1/transforms/transform_2pa0czI6QRKPq7zsC59hfA9TcNh/results
# None
# Error during processing: Error fetching results: 504 Server Error: Gateway Time-out for url: https://api.runtrellis.com/v1/transforms/transform_2pa0lN7vmqcEKlr5Dne3j75duLW/results
# None
# 19/12/2022
# 15/12/2022
# 14/12/2022
# 20/12/2022
# Error during processing: Error fetching results: 504 Server Error: Gateway Time-out for url: https://api.runtrellis.com/v1/transforms/transform_2pa1DdVKbkN6GOqyNTdDccJl5S1/results
# None
# Date not found.
# 09/12/2022
# 08/12/2022
# 22/12/2022
# 12/12/2022
# 27/12/2022
# 15/12/2022
# Error during processing: Error fetching results: 504 Server Error: Gateway Time-out for url: https://api.runtrellis.com/v1/transforms/transform_2pa1uALKrptmUSoMb0EMqUxLOQR/results
# None
# 16/12/2022
# 02/12/2022
# 19/12/2022
# 13/02/2023
# 14/12/2022
# Date not found.
# 13/12/2022
# 13/12/2022
# 13/12/2022
# 13/12/2022
# 13/12/2022
# 13/12/2022
# Error during processing: Error fetching results: 504 Server Error: Gateway Time-out for url: https://api.runtrellis.com/v1/transforms/transform_2pa34WWye3GRzjymWYxhDBIgOrE/results
# None
# 13/12/2022
# 09/12/2022
# Error during processing: Error fetching results: 504 Server Error: Gateway Time-out for url: https://api.runtrellis.com/v1/transforms/transform_2pa3MlgMUyCpA8LpE3v9UMyaI87/results
# None
# 21/03/2023
# Error during processing: Error fetching results: 504 Server Error: Gateway Time-out for url: https://api.runtrellis.com/v1/transforms/transform_2pa3d29hN9LUS4yywiwipEYBtQi/results
# None
# 24/02/2020
# 24/01/2020
# 24/01/2020
# 28/01/2020
# 06/01/2020
# 28/01/2020
# 27/02/2020
# Error during processing: Error fetching results: 504 Server Error: Gateway Time-out for url: https://api.runtrellis.com/v1/transforms/transform_2pa4Ln5XEWOj0pnpKqoimgb9spz/results
# None
# 12/02/2020
# 11/2019
# 06/02/2020
# 13/02/2020
# Error during processing: Error fetching results: 504 Server Error: Gateway Time-out for url: https://api.runtrellis.com/v1/transforms/transform_2pa4qDxea6S5mAukdnsJYu5pGCQ/results
# None
# 14/02/2020
# Date not found.
# Date not found.
# 21/12/2012
# 10/02/2020
# Error during processing: Error fetching results: 504 Server Error: Gateway Time-out for url: https://api.runtrellis.com/v1/transforms/transform_2pa5KIZCLFH83oQX0kN8foU9lW5/results
# None
# 06/03/2020
# 01/01/2020
# 22/01/2020
# 04/06/2020
# 07/02/2020
# 21/05/2019
# Date not found.
# 07/05/2020
# 03/10/2022
# Date not found.
# 28/06/2022
# Error during processing: Error fetching results: 504 Server Error: Gateway Time-out for url: https://api.runtrellis.com/v1/transforms/transform_2pa6RXt6ratJGrj55ogsBqciDZC/results
# None
# Error during processing: Error fetching results: 504 Server Error: Gateway Time-out for url: https://api.runtrellis.com/v1/transforms/transform_2pa6ZyeKFVRcMLOw238oMaWFVDg/results
# None
# 22/06/2022
# 08/06/2022
# 30/06/2022
# Error during processing: Error fetching results: 504 Server Error: Gateway Time-out for url: https://api.runtrellis.com/v1/transforms/transform_2pa6y4AbfB6mIituCmyBahq7Apj/results
# None
# 28/06/2022
# Error during processing: Error fetching results: 504 Server Error: Gateway Time-out for url: https://api.runtrellis.com/v1/transforms/transform_2pa79ocG2iJysONbeKGpDHbOPpo/results
# None
# 24/06/2022
# 27/06/2022
# Error during processing: Error fetching results: 504 Server Error: Gateway Time-out for url: https://api.runtrellis.com/v1/transforms/transform_2pa7SGyMpS0KUaFwZWtUrBvTqf0/results
# None
# 15/12/2022
# 15/06/2022
# 19/10/2023
# 5/3/2024
# 07/02/2024
# 15/12/2022
# Error during processing: Error fetching results: 504 Server Error: Gateway Time-out for url: https://api.runtrellis.com/v1/transforms/transform_2pa89QKIekcBNc7Vpm1WO66jxc8/results
# None
# 27/09/2023
# 20/03/2024
# 15/12/2022
# Date not found.
# 13/10/2022
# 11/12/2020
# 15/12/2022
# 25/06/2013
# 12/10/2023
# 20/12/2018
# 29/05/2020
# 07/05/2020
# Error during processing: Error fetching results: 504 Server Error: Gateway Time-out for url: https://api.runtrellis.com/v1/transforms/transform_2pa9PlJOYnL8NYhTqp8AgGihXlp/results
# None
# 10/10/2023
# 29/02/2024
# 28/04/2023
# Error during processing: Error fetching results: 504 Server Error: Gateway Time-out for url: https://api.runtrellis.com/v1/transforms/transform_2pa9rSxFgpdbmcRg5z859bkYU03/results
# None
# Error during processing: Error fetching results: 504 Server Error: Gateway Time-out for url: https://api.runtrellis.com/v1/transforms/transform_2pa9ztA7CW5pM1NtlAyCLjncdg5/results
# None
# 11/12/2023
# Error during processing: Error fetching results: 504 Server Error: Gateway Time-out for url: https://api.runtrellis.com/v1/transforms/transform_2paAFGre2pvUYVyBhthb0gjjrd9/results
# None
# 08/03/2024
# 29/03/2024
# Date not found
# 23/06/2022
# Error during processing: Error fetching results: 504 Server Error: Gateway Time-out for url: https://api.runtrellis.com/v1/transforms/transform_2paAictMyUEgvvbjfiKHAc9YvGy/results
# None
# 08/06/2022
# 10/05/2022
# 27/06/2022
# 22/09/2022
# 21/12/2023
# 02/11/2020
# 06/01/2021
# 07/11/2016
# Date not found.
# 21/04/2021
# 20/10/2021
# 13/02/2024
# 04/04/2024
# Error during processing: Error fetching results: 504 Server Error: Gateway Time-out for url: https://api.runtrellis.com/v1/transforms/transform_2paC2sy1iCoSa48Rq0ezbpAxAcA/results
# None
# 29/03/2024
# Error during processing: Error fetching results: 504 Server Error: Gateway Time-out for url: https://api.runtrellis.com/v1/transforms/transform_2paCGWVDV3TaASzE6l5iRrHeW7R/results
# None
# 29/03/2024
# 08/07/2021
# Error during processing: Error fetching results: 504 Server Error: Gateway Time-out for url: https://api.runtrellis.com/v1/transforms/transform_2paCb5xXjRcG0LsHvEa7TxuX8Nd/results
# None
# Error during processing: Error fetching results: 504 Server Error: Gateway Time-out for url: https://api.runtrellis.com/v1/transforms/transform_2paCjaUTZdNV6YM7gZ7misUwNG4/results
# None
# 27/03/2024
# 17/07/2023
# 11/07/2023
# 06/07/2023
# 03/03/2022
# 03/03/2022
# 06/04/2023
# Error during processing: Error fetching results: 504 Server Error: Gateway Time-out for url: https://api.runtrellis.com/v1/transforms/transform_2paDXUSCYvlNCgNiSTrv7py1nj8/results
# None
# 14/03/2022
# 17/03/2022
# 05/04/2022
# 04/04/2022
# 21/04/2022
# 23/05/2022
# 20/05/2022
# Error during processing: Error fetching results: 504 Server Error: Gateway Time-out for url: https://api.runtrellis.com/v1/transforms/transform_2paEJOxwsujfSj7EfIpUMqsEAkz/results
# None
# 24/05/2022
# 02/05/2022
# 18/05/2022
# Error during processing: Error fetching results: 504 Server Error: Gateway Time-out for url: https://api.runtrellis.com/v1/transforms/transform_2paEiylI2UaW6i1Z17TMBv3zoXx/results
# None
# Error during processing: Error fetching results: 504 Server Error: Gateway Time-out for url: https://api.runtrellis.com/v1/transforms/transform_2paErTuRuH0P1ZVM7ogOIIY3Ujm/results
# None
# Error during processing: Error fetching results: 504 Server Error: Gateway Time-out for url: https://api.runtrellis.com/v1/transforms/transform_2paEzsnbuISob9oYhjq1xMmkusp/results
# None
# 11/05/2022
# 24/05/2022
# Error during processing: Error fetching results: 504 Server Error: Gateway Time-out for url: https://api.runtrellis.com/v1/transforms/transform_2paFO2bWgii1cNuNv5rul3Cba8P/results
# None
# 11/05/2022
# Error during processing: Error fetching results: 504 Server Error: Gateway Time-out for url: https://api.runtrellis.com/v1/transforms/transform_2paFbdd2zefAKQkDzJwvKJZa2Bm/results
# None
# Error during processing: Error fetching results: 504 Server Error: Gateway Time-out for url: https://api.runtrellis.com/v1/transforms/transform_2paFk7UZv5yQS28t8v6fogYHSdA/results
# None
# 18/05/2022
# 09/05/2022
# 28/10/2022
# 06/03/2023
# 16/05/2022
# 13/04/2022
# Error during processing: Error fetching results: 504 Server Error: Gateway Time-out for url: https://api.runtrellis.com/v1/transforms/transform_2paGMhLivVuShyAV47LjQHgG3o5/results
# None
# Error during processing: Error fetching results: 504 Server Error: Gateway Time-out for url: https://api.runtrellis.com/v1/transforms/transform_2paGV3G78tYtncpFExySN87RGz1/results
# None
# 20/09/2022
# 12/04/2022
# 30/03/2022
# 16/03/2022
# 27/12/2023
# 14/04/2022
# 19/05/2022
# 12/07/2022
# 07/07/2022
# 23/01/2014
# 20/05/2022
# Error during processing: Error fetching results: 504 Server Error: Gateway Time-out for url: https://api.runtrellis.com/v1/transforms/transform_2paHd7bT2M1QJki9A7zjK3cxBAT/results
# None
# 24/05/2022
# 29/03/2022
# 03/02/2022
# 22/03/2022
# 02/03/2016
# Error during processing: Error fetching results: 504 Server Error: Gateway Time-out for url: https://api.runtrellis.com/v1/transforms/transform_2paIBrNBDQPkNARUC4VDajVxNYC/results
# None
# 22/03/2022
# Error during processing: Error fetching results: 504 Server Error: Gateway Time-out for url: https://api.runtrellis.com/v1/transforms/transform_2paIRmR6eugNLNsArzEI3yq8gkB/results
# None
# Error during processing: Error fetching results: 504 Server Error: Gateway Time-out for url: https://api.runtrellis.com/v1/transforms/transform_2paIaC2i7DrYWpu7oWCzk5NxMSA/results
# None
# Date not found.
# 31/03/2022
# 18/12/2023
# 13/04/2022
# 03/10/2022
# 25/08/2022
# 10/03/2022
# 04/03/2022
# Date not found.
# 31/05/2016
# Error during processing: Error fetching results: 504 Server Error: Gateway Time-out for url: https://api.runtrellis.com/v1/transforms/transform_2paJaYhedKfkLrd9CAiHcBcywwC/results
# None
# Error during processing: Error fetching results: 504 Server Error: Gateway Time-out for url: https://api.runtrellis.com/v1/transforms/transform_2paJiyQRDGG2R5tAxI0mvsI98Nn/results
# None
# Date not found.
# 22/12/2023
# Error during processing: Error fetching results: 504 Server Error: Gateway Time-out for url: https://api.runtrellis.com/v1/transforms/transform_2paK3GoTPo1QoJJVH6rcANAlM9X/results
# None
# 25/09/2020
# 07/10/2020
# 12/10/2020
# 16/11/2020
# 20/11/2020
# 23/11/2020
# 16/11/2020
# Error during processing: Error fetching results: 504 Server Error: Gateway Time-out for url: https://api.runtrellis.com/v1/transforms/transform_2paKjvlwiZVVDVlM0MBZnevGI0A/results
# None
# 30/11/2020
# 05/10/2020
# 06/10/2020
# 06/10/2020
# 08/02/2021
# 04/02/2021
# Error during processing: Error fetching results: 504 Server Error: Gateway Time-out for url: https://api.runtrellis.com/v1/transforms/transform_2paLO9RBXKtTOIG1PZ2DrbzWowQ/results
# None
# 14/09/2020
# Error during processing: Error fetching results: 504 Server Error: Gateway Time-out for url: https://api.runtrellis.com/v1/transforms/transform_2paLb9Fs4axbh79sAz7yC0Zknwv/results
# None
# 06/10/2020
# 30/09/2020
# 10/07/2020
# 04/09/2020
# 26/12/2023
# 11/12/2023
# 23/12/2020
# 25/01/2024
# 17/11/2020
# 17/11/2020
# 03/11/2020
# 10/11/2020
# 09/09/2020
# 21/06/2017
# Date not found.
# 21/09/2020
# 10/09/2021
# 29/09/2020
# 29/09/2020
# Error during processing: Error fetching results: 504 Server Error: Gateway Time-out for url: https://api.runtrellis.com/v1/transforms/transform_2paNN2xWVZE4SmaqtopJNu5tU5m/results
# None
# 29/09/2020
# Error during processing: Error fetching results: 504 Server Error: Gateway Time-out for url: https://api.runtrellis.com/v1/transforms/transform_2paNasODI10RfGc2LIX6O3DX7HW/results
# None
# 31/08/2020
# 03/08/2020
# 18/10/2023
# 01/12/2023
# 12/02/2024
# 18/06/2020
# 19/06/2020
# 15/03/2020
# 05/06/2020
# Error during processing: Error fetching results: 504 Server Error: Gateway Time-out for url: https://api.runtrellis.com/v1/transforms/transform_2paOaIxpBlugmFowFlsfKXdfC08/results
# None
# 28/05/2020
# 28/05/2020
# 25/03/2013
# Error during processing: Error fetching results: 504 Server Error: Gateway Time-out for url: https://api.runtrellis.com/v1/transforms/transform_2paOx8JmRqkzXmtehS6ztbJhCYH/results
# None
# 05/07/2020
# 06/07/2020
# Error during processing: Error fetching results: 504 Server Error: Gateway Time-out for url: https://api.runtrellis.com/v1/transforms/transform_2paPGLmMG2lILcDuN99s7KBg1lL/results
# None
# Error during processing: Error fetching results: 504 Server Error: Gateway Time-out for url: https://api.runtrellis.com/v1/transforms/transform_2paPOuKLQXaGzyuDyI9QK6WZmBH/results
# None
# 10/07/2020
# 09/07/2020
# Error during processing: Error fetching results: 504 Server Error: Gateway Time-out for url: https://api.runtrellis.com/v1/transforms/transform_2paPgRG1ooF0m3s0X7C6KVgoCm7/results
# None
# Date not found.
# 20/12/2023
# 19/12/2023
# 21/03/2024
# Error during processing: Error fetching results: 504 Server Error: Gateway Time-out for url: https://api.runtrellis.com/v1/transforms/transform_2paQ87YnDYAulcCK17bF40EY1JI/results
# None
# Error during processing: Error fetching results: 504 Server Error: Gateway Time-out for url: https://api.runtrellis.com/v1/transforms/transform_2paQGaVq3FXsKkOtqptBrfFoJHh/results
# None
# Date not found.
# 03/04/2024
# 03/04/2024
# 06/04/2023
# 11/03/2024
# 29/06/2023
# Error during processing: Error fetching results: 504 Server Error: Gateway Time-out for url: https://api.runtrellis.com/v1/transforms/transform_2paQz2DC3QQn2zZ2cws8ukDgBrD/results
# None
# Error during processing: Error fetching results: 504 Server Error: Gateway Time-out for url: https://api.runtrellis.com/v1/transforms/transform_2paR7OIumlmpkrQXatNoaju4wOj/results
# None
# Error during processing: Error fetching results: 504 Server Error: Gateway Time-out for url: https://api.runtrellis.com/v1/transforms/transform_2paRFpRCTWePihpPKBb8XLUGTpU/results
# None
# 15/04/2022
# 28/11/2023
# Error during processing: Error fetching results: 504 Server Error: Gateway Time-out for url: https://api.runtrellis.com/v1/transforms/transform_2paRZvAvItUMINA4w0hPYhPe0wK/results
# None
# 08/04/2024
# 14/12/2020
# 14/12/2020
# Error during processing: Error fetching results: 504 Server Error: Gateway Time-out for url: https://api.runtrellis.com/v1/transforms/transform_2paRxtUpMQkme7fMaB5tOsIrAqM/results
# None
# Error during processing: Error fetching results: 504 Server Error: Gateway Time-out for url: https://api.runtrellis.com/v1/transforms/transform_2paS6FT8UrVeNMsw0xMMOQwfvmy/results
# None
# 14/12/2020
# 19/12/2020
# Date not found.
# Error during processing: Error fetching results: 504 Server Error: Gateway Time-out for url: https://api.runtrellis.com/v1/transforms/transform_2paSSk7gk3pDM6XMLETCfymEycC/results
# None
# Error during processing: Error fetching results: 504 Server Error: Gateway Time-out for url: https://api.runtrellis.com/v1/transforms/transform_2paSbGUgverkoumDGCKiq6EXpaV/results
# None
# 17/06/2020
# 05/03/2020
# Error during processing: Error fetching results: 504 Server Error: Gateway Time-out for url: https://api.runtrellis.com/v1/transforms/transform_2paSvnl4GSFZwbz758YrUfzpyLV/results
# None
# 03/03/2020
# 15/02/2021
# 16/12/2020
# 14/12/2020
# 17/12/2015
# 04/12/2020
# Error during processing: Error fetching results: 504 Server Error: Gateway Time-out for url: https://api.runtrellis.com/v1/transforms/transform_2paTdO9OMsJTCG5qSNh3RwHS4o7/results
# None
# 15/12/2020
# 15/12/2020
# 14/12/2020
# 14/12/2020
# 30/07/2020
# 11/06/2020
# 28/06/2022
# 30/06/2020
# 18/03/2024
# 19/06/2020
# 25/06/2020
# 14/12/2020
# 23/07/2020
# Error during processing: Error fetching results: 504 Server Error: Gateway Time-out for url: https://api.runtrellis.com/v1/transforms/transform_2paUr51P1YpGQOFDAYL3vCxCFn4/results
# None
# 07/07/2020
# Error during processing: Error fetching results: 504 Server Error: Gateway Time-out for url: https://api.runtrellis.com/v1/transforms/transform_2paV6PVoKKEZiqrNUo9kJypNTqy/results
# None
# 16/07/2020
# Error during processing: Error fetching results: 504 Server Error: Gateway Time-out for url: https://api.runtrellis.com/v1/transforms/transform_2paVKg16uU39CMGUgLcxutPmuPP/results
# None
# Error during processing: Error fetching results: 504 Server Error: Gateway Time-out for url: https://api.runtrellis.com/v1/transforms/transform_2paVT8LOGBYOMrmvMVb9IVMcnl8/results
# None
# 21/12/2023
# 06/02/2024
# Date not found.
# 02/04/2022
# 22/11/2022
# 21/12/2023
# 22/12/2023

# %%
df['extracted_date'] = df['pdf_url'].map(url_date_map)

# %%
df.head(10)
# Out:
#                                              pdf_url   gold_date  \
# 0  https://datapolitics-public.s3.gra.io.cloud.ov...  16/01/2023
# 1  https://datapolitics-public.s3.gra.io.cloud.ov...  25/01/2023
# 2  https://datapolitics-public.s3.gra.io.cloud.ov...  02/02/2023
# 3  https://datapolitics-public.s3.gra.io.cloud.ov...  26/01/2023
# 4  https://datapolitics-public.s3.gra.io.cloud.ov...  16/01/2023
# 5  https://datapolitics-public.s3.gra.io.cloud.ov...  16/02/2023
# 6  https://datapolitics-public.s3.gra.io.cloud.ov...  22/02/2023
# 7  https://datapolitics-public.s3.gra.io.cloud.ov...  13/02/2023
# 8  https://datapolitics-public.s3.gra.io.cloud.ov...  09/03/2023
# 9  https://datapolitics-public.s3.gra.io.cloud.ov...  15/02/2023
#
#   extracted_date
# 0     16/01/2023
# 1     25/01/2023
# 2     02/02/2023
# 3     26/01/2023
# 4     16/01/2023
# 5     16/02/2023
# 6            NaN
# 7     13/02/2023
# 8            NaN
# 9     15/02/2023

# %%
num_nan_rows = df['extracted_date'].isna().sum()
num_nan_rows
# Out:
# 91

# %%
num_no_date_rows = df[df['extracted_date'] == 'Date not found.'].count()
num_no_date_rows
# Out:
# pdf_url           18
# gold_date         18
# extracted_date    18
# dtype: int64

# %%
valid_rows = df.dropna(subset=['gold_date', 'extracted_date'])

matches = (valid_rows['gold_date'] == valid_rows['extracted_date']).sum()
total_valid = len(valid_rows)
accuracy = matches / total_valid

print(f"Total matches: {matches}")
print(f"Total pdfs that have been successfully processed: {total_valid}")
print(f"Accuracy: {accuracy:.4%}")
# Out:
# Total matches: 274
# Total pdfs that have been successfully processed: 355
# Accuracy: 77.1831%

# %% [markdown]
# * Out of 468 rows in the annotated dataset, 91 could not be processed by Trellis, either the link to the URL denied the access or the file was too large to be processed.
# * For 18 of the rows Trellis could not find a date!
# * Final accuracy is: 74.6479%

# %% [markdown]
# # How to use?

# %% [markdown]
# 1. Define your url in the `pdf_url`
# 2. Pass the url to `process_publication_dates` method
# 3. The result of the method can be:
#     - None (in case the API couldn't process the uploaded pdf url)
#     - 'Date not found.' (when Trellis could not find any matched date)
#     - the extracted date in DD/MM/YYYY format.

# %%
pdf_url = ""
extracted_date = process_publication_dates(pdf_url)
print(extracted_date)
